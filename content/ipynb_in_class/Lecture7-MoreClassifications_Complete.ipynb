# %% [markdown]
# # Lecture 7 Ensemble Methods

# %%
# %matplotlib inline
# import necessary libraries and specify that graphs should be plotted inline. 
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Ensemble Methods
#
# We will work on four topics under ensemble methods: (1) voting classifier, (2) bagging, (3) random forest, and (4) AdaBoost. To show the value of ensemble methods, we use with a classification problem that is NOT linear separable. In below, we first generate and split the data.

# %% [markdown]
# ### 0. Data Prep

# %% [markdown]
# Using syntax: sklearn.datasets.make_moons(), we can generate a dataset where points form up two moon shapes. This is often used to show how our classifier works for non-linear separable cases.

# %%
# Data Generation
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=500, noise=0.30, random_state=42)
# make_moons() will generate two moon-shaped datasets

# %%
# Data Splittion
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Visualize our data
plt.scatter(X_train[:,0], X_train[:, 1], c=y_train)

# %% [markdown]
# ### 1. Voting Classifier

# %% [markdown]
# Voting classifier will take the result of multiple classification models to make the final prediction (based on majority vote). Therefore, we need to specify a couple of classification models first. Note that in practice, this process is more natural. Suppose we try different models and are debating on which one to choose. Voting classifier is saying that, we can combine the result instead of choosing only one of them.
#
# The process is realized through syntax:
# **<center>sklearn.ensemble.VotingClassifier</center>**
# - estimators: the models to use. You need to define a list to store all the models. Each element of a list should include two elements: ('MODEL_NAME', model). The 'MODEL_NAME' is a string.
# - voting: the voting method. If "hard", then vote based on predicted label. If "soft", then vote based on predicted probability (i.e., mean of P(y=1)). Default is "hard".
#
# Similar to other models, use .fit() to train the model, use .predict() for prediction, use .score() for accuracy.
#
#
# **Practice:**
#
# Suppose we want to combine the result of three classifiers: (1) Logistic Regression, (2) Decision Tree, and (3) Naive Bayes.
# - What is the model performance of my voting classifier?
# - What is the model performance of each classifier by itself?

# %%
# S1: Define Functions/Estimators

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

log_clf = LogisticRegression(random_state=42)
dt_clf = DecisionTreeClassifier(random_state=42, criterion='entropy')
nbg_clf = GaussianNB()

# %%
# S2: Apply Voting Classifier

from sklearn.ensemble import VotingClassifier

# define voting classifier
voting_clf = VotingClassifier(estimators=[('lr1', log_clf), ('dt', dt_clf), ('nbg', nbg_clf)], voting='hard')

# train the model
voting_clf.fit(X_train, y_train)

# Performance Measure
print("Test score for voting classifier is:", voting_clf.score(X_test, y_test))
# Out:
# Test score for voting classifier is: 0.856

# %% [markdown]
# #### Extension: Using Loop for Automation
# To compare the accuracy, we can run each model manually and print the test score. However, we can also use a loop to automate this process.

# %%
for clf in (log_clf, nbg_clf, dt_clf, voting_clf):
    clf.fit(X_train, y_train)
    print(clf.__class__.__name__, clf.score(X_test, y_test))
    
# The trick is to find model name automatically. This is realized using: 
## clf.__class__.__name__
## Intuitively, it means: 
## for the current clf, find its model (__class__), then get its model name (__name__)
# Out:
# LogisticRegression 0.864
# GaussianNB 0.856
# DecisionTreeClassifier 0.832
# VotingClassifier 0.856

# %% [markdown]
# ### 2. Bagging Ensemble

# %% [markdown]
# Bagging will apply **one same** model on multiple **different resampled** training sets. Suppose each time, we use $B$ records to train our model, and we want to train our model $K$ times. This case, we will have $K$ different prediction results, and we would like to combine these results for our final prediction.
#
#
# Based on the above-shown process, we need to specify: (1) the model to use, (2) how many records to take each time (i.e., $B$), and (3) how many times to train our model (i.e., $K$). In Python, it can be realized using syntax:
#
# **<center>sklearn.ensemble.BaggingClassifier()</center>**
# We need to specify:
# - estimator, the model to use (e.g., logistic regression, knn, decision tree, svm, etc.) This should be specified in the first element.
# - n_estimators, the number of times to run the model, i.e., $K$.
# - max_samples, the number of records to use to train the model, i.e., $B$.
# - bootstrap, whether sample with/without replacement. Default: True.
# - random_state, for replication (resampling procedure)
#
# **Practice:**
# Suppose we want to run decision tree with default setting on multiple samples, then combine the results. Specifically, we want to run the model 200 times (i.e., N=200), each time with sample size 100 (i.e., B=100).

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=42)

bag_clf = BaggingClassifier(dt,
                           n_estimators=200,
                           max_samples=100,
                           bootstrap=True, random_state=42)
bag_clf.fit(X_train, y_train)
print(bag_clf.score(X_test, y_test))
# Out:
# 0.904

# %% [markdown]
# **Practice:**
# Now run the naive decision tree classifier. What is the accuracy for test set?

# %%
# Practice for you
dt.fit(X_train, y_train)
print(dt.score(X_test, y_test))
# Out:
# 0.856

# %% [markdown]
# ### 3. Random Forest

# %% [markdown]
# Random Forest can be realized using:
# **<center>sklearn.ensemble.RandomForestClassifier</center>**
#
# Recall that Random Forest is an implementation of ensemble learning (bagging) on decision tree models. Thus, most (if not all) the parameters in bagging and decision tree are applicable. Below, we emphasize a couple of parameters:
#
# - n_estimators: number of trees in the forest/number of times to run decision tree
# - max_samples: number of records to sample for each tree
# - max_features: number of features to choose (the $m$ in the lecture note)
# - bootstrap: True when sample with replacement

# %%
from sklearn.ensemble import RandomForestClassifier

rnd_clf = RandomForestClassifier(n_estimators=200, 
                                 max_samples=100, 
                                 random_state=42)
rnd_clf.fit(X_train, y_train)
print(rnd_clf.score(X_test, y_test))
# Out:
# 0.92

# %% [markdown]
# ### 4. AdaBoost

# %% [markdown]
# AdaBoost focuses on one classifier as well. The key difference between AdaBoost and Bagging is that, it applies different weights to samples, and combine results using a weighted method.
#
# The method is realized using syntax:
# **<center>sklearn.ensemble.AdaBoostClassifier</center>**
# - The first element should be the model we use.
# - n_estimators: number of times to run the model
# - learning_rate: the importance of each classifier. default is 1.
# - random_state

# %%
from sklearn.ensemble import AdaBoostClassifier

# Define base model
naive_dt = DecisionTreeClassifier(max_depth=1)

# AdaBoost
ada_clf = AdaBoostClassifier(naive_dt, 
                             n_estimators=200, 
                             learning_rate=0.5,
                             random_state=42)

ada_clf.fit(X_train, y_train)

# Performance
print(ada_clf.score(X_test, y_test))

ada_clf.estimators_
# Out:
# 0.896
# [DecisionTreeClassifier(max_depth=1, random_state=1608637542),
#  DecisionTreeClassifier(max_depth=1, random_state=1273642419),
#  DecisionTreeClassifier(max_depth=1, random_state=1935803228),
#  DecisionTreeClassifier(max_depth=1, random_state=787846414),
#  DecisionTreeClassifier(max_depth=1, random_state=996406378),
#  DecisionTreeClassifier(max_depth=1, random_state=1201263687),
#  DecisionTreeClassifier(max_depth=1, random_state=423734972),
#  DecisionTreeClassifier(max_depth=1, random_state=415968276),
#  DecisionTreeClassifier(max_depth=1, random_state=670094950),
#  DecisionTreeClassifier(max_depth=1, random_state=1914837113),
#  DecisionTreeClassifier(max_depth=1, random_state=669991378),
#  DecisionTreeClassifier(max_depth=1, random_state=429389014),
#  DecisionTreeClassifier(max_depth=1, random_state=249467210),
#  DecisionTreeClassifier(max_depth=1, random_state=1972458954),
#  DecisionTreeClassifier(max_depth=1, random_state=1572714583),
#  DecisionTreeClassifier(max_depth=1, random_state=1433267572),
#  DecisionTreeClassifier(max_depth=1, random_state=434285667),
#  DecisionTreeClassifier(max_depth=1, random_state=613608295),
#  DecisionTreeClassifier(max_depth=1, random_state=893664919),
#  DecisionTreeClassifier(max_depth=1, random_state=648061058),
#  DecisionTreeClassifier(max_depth=1, random_state=88409749),
#  DecisionTreeClassifier(max_depth=1, random_state=242285876),
#  DecisionTreeClassifier(max_depth=1, random_state=2018247425),
#  DecisionTreeClassifier(max_depth=1, random_state=953477463),
#  DecisionTreeClassifier(max_depth=1, random_state=1427830251),
#  DecisionTreeClassifier(max_depth=1, random_state=1883569565),
#  DecisionTreeClassifier(max_depth=1, random_state=911989541),
#  DecisionTreeClassifier(max_depth=1, random_state=3344769),
#  DecisionTreeClassifier(max_depth=1, random_state=780932287),
#  DecisionTreeClassifier(max_depth=1, random_state=2114032571),
#  DecisionTreeClassifier(max_depth=1, random_state=787716372),
#  DecisionTreeClassifier(max_depth=1, random_state=504579232),
#  DecisionTreeClassifier(max_depth=1, random_state=1306710475),
#  DecisionTreeClassifier(max_depth=1, random_state=479546681),
#  DecisionTreeClassifier(max_depth=1, random_state=106328085),
#  DecisionTreeClassifier(max_depth=1, random_state=30349564),
#  DecisionTreeClassifier(max_depth=1, random_state=1855189739),
#  DecisionTreeClassifier(max_depth=1, random_state=99052376),
#  DecisionTreeClassifier(max_depth=1, random_state=1250819632),
#  DecisionTreeClassifier(max_depth=1, random_state=106406362),
#  DecisionTreeClassifier(max_depth=1, random_state=480404538),
#  DecisionTreeClassifier(max_depth=1, random_state=1717389822),
#  DecisionTreeClassifier(max_depth=1, random_state=599121577),
#  DecisionTreeClassifier(max_depth=1, random_state=200427519),
#  DecisionTreeClassifier(max_depth=1, random_state=1254751707),
#  DecisionTreeClassifier(max_depth=1, random_state=2034764475),
#  DecisionTreeClassifier(max_depth=1, random_state=1573512143),
#  DecisionTreeClassifier(max_depth=1, random_state=999745294),
#  DecisionTreeClassifier(max_depth=1, random_state=1958805693),
#  DecisionTreeClassifier(max_depth=1, random_state=389151677),
#  DecisionTreeClassifier(max_depth=1, random_state=1224821422),
#  DecisionTreeClassifier(max_depth=1, random_state=508464061),
#  DecisionTreeClassifier(max_depth=1, random_state=857592370),
#  DecisionTreeClassifier(max_depth=1, random_state=1642661739),
#  DecisionTreeClassifier(max_depth=1, random_state=61136438),
#  DecisionTreeClassifier(max_depth=1, random_state=2075460851),
#  DecisionTreeClassifier(max_depth=1, random_state=396917567),
#  DecisionTreeClassifier(max_depth=1, random_state=2004731384),
#  DecisionTreeClassifier(max_depth=1, random_state=199502978),
#  DecisionTreeClassifier(max_depth=1, random_state=1545932260),
#  DecisionTreeClassifier(max_depth=1, random_state=461901618),
#  DecisionTreeClassifier(max_depth=1, random_state=774414982),
#  DecisionTreeClassifier(max_depth=1, random_state=732395540),
#  DecisionTreeClassifier(max_depth=1, random_state=1934879560),
#  DecisionTreeClassifier(max_depth=1, random_state=279394470),
#  DecisionTreeClassifier(max_depth=1, random_state=56972561),
#  DecisionTreeClassifier(max_depth=1, random_state=1927948675),
#  DecisionTreeClassifier(max_depth=1, random_state=1899242072),
#  DecisionTreeClassifier(max_depth=1, random_state=1999874363),
#  DecisionTreeClassifier(max_depth=1, random_state=271820813),
#  DecisionTreeClassifier(max_depth=1, random_state=1324556529),
#  DecisionTreeClassifier(max_depth=1, random_state=1655351289),
#  DecisionTreeClassifier(max_depth=1, random_state=1308306184),
#  DecisionTreeClassifier(max_depth=1, random_state=68574553),
#  DecisionTreeClassifier(max_depth=1, random_state=419498548),
#  DecisionTreeClassifier(max_depth=1, random_state=991681409),
#  DecisionTreeClassifier(max_depth=1, random_state=791274835),
#  DecisionTreeClassifier(max_depth=1, random_state=1035196507),
#  DecisionTreeClassifier(max_depth=1, random_state=1890440558),
#  DecisionTreeClassifier(max_depth=1, random_state=787110843),
#  DecisionTreeClassifier(max_depth=1, random_state=524150214),
#  DecisionTreeClassifier(max_depth=1, random_state=472432043),
#  DecisionTreeClassifier(max_depth=1, random_state=2126768636),
#  DecisionTreeClassifier(max_depth=1, random_state=1431061255),
#  DecisionTreeClassifier(max_depth=1, random_state=147697582),
#  DecisionTreeClassifier(max_depth=1, random_state=744595490),
#  DecisionTreeClassifier(max_depth=1, random_state=1758017741),
#  DecisionTreeClassifier(max_depth=1, random_state=1679592528),
#  DecisionTreeClassifier(max_depth=1, random_state=1111451555),
#  DecisionTreeClassifier(max_depth=1, random_state=782698033),
#  DecisionTreeClassifier(max_depth=1, random_state=698027879),
#  DecisionTreeClassifier(max_depth=1, random_state=1096768899),
#  DecisionTreeClassifier(max_depth=1, random_state=1338788865),
#  DecisionTreeClassifier(max_depth=1, random_state=1826030589),
#  DecisionTreeClassifier(max_depth=1, random_state=86191493),
#  DecisionTreeClassifier(max_depth=1, random_state=893102645),
#  DecisionTreeClassifier(max_depth=1, random_state=200619113),
#  DecisionTreeClassifier(max_depth=1, random_state=290770691),
#  DecisionTreeClassifier(max_depth=1, random_state=793943861),
#  DecisionTreeClassifier(max_depth=1, random_state=134489564),
#  DecisionTreeClassifier(max_depth=1, random_state=2016850622),
#  DecisionTreeClassifier(max_depth=1, random_state=1470101905),
#  DecisionTreeClassifier(max_depth=1, random_state=1181686489),
#  DecisionTreeClassifier(max_depth=1, random_state=1931679275),
#  DecisionTreeClassifier(max_depth=1, random_state=1887633569),
#  DecisionTreeClassifier(max_depth=1, random_state=1697157321),
#  DecisionTreeClassifier(max_depth=1, random_state=1695770557),
#  DecisionTreeClassifier(max_depth=1, random_state=1832485859),
#  DecisionTreeClassifier(max_depth=1, random_state=420477197),
#  DecisionTreeClassifier(max_depth=1, random_state=976125790),
#  DecisionTreeClassifier(max_depth=1, random_state=1811936047),
#  DecisionTreeClassifier(max_depth=1, random_state=1402481934),
#  DecisionTreeClassifier(max_depth=1, random_state=380072391),
#  DecisionTreeClassifier(max_depth=1, random_state=302554573),
#  DecisionTreeClassifier(max_depth=1, random_state=841739990),
#  DecisionTreeClassifier(max_depth=1, random_state=89482491),
#  DecisionTreeClassifier(max_depth=1, random_state=194249720),
#  DecisionTreeClassifier(max_depth=1, random_state=1980718781),
#  DecisionTreeClassifier(max_depth=1, random_state=1397283111),
#  DecisionTreeClassifier(max_depth=1, random_state=1479761620),
#  DecisionTreeClassifier(max_depth=1, random_state=1669356239),
#  DecisionTreeClassifier(max_depth=1, random_state=1062231788),
#  DecisionTreeClassifier(max_depth=1, random_state=1165435217),
#  DecisionTreeClassifier(max_depth=1, random_state=170476398),
#  DecisionTreeClassifier(max_depth=1, random_state=1411916852),
#  DecisionTreeClassifier(max_depth=1, random_state=372593431),
#  DecisionTreeClassifier(max_depth=1, random_state=1532243865),
#  DecisionTreeClassifier(max_depth=1, random_state=1998256344),
#  DecisionTreeClassifier(max_depth=1, random_state=1206604539),
#  DecisionTreeClassifier(max_depth=1, random_state=459708603),
#  DecisionTreeClassifier(max_depth=1, random_state=183378299),
#  DecisionTreeClassifier(max_depth=1, random_state=1185407468),
#  DecisionTreeClassifier(max_depth=1, random_state=605264936),
#  DecisionTreeClassifier(max_depth=1, random_state=1272485020),
#  DecisionTreeClassifier(max_depth=1, random_state=1297926158),
#  DecisionTreeClassifier(max_depth=1, random_state=709816108),
#  DecisionTreeClassifier(max_depth=1, random_state=320192576),
#  DecisionTreeClassifier(max_depth=1, random_state=67157848),
#  DecisionTreeClassifier(max_depth=1, random_state=2091163462),
#  DecisionTreeClassifier(max_depth=1, random_state=1818495496),
#  DecisionTreeClassifier(max_depth=1, random_state=1169282391),
#  DecisionTreeClassifier(max_depth=1, random_state=1696003200),
#  DecisionTreeClassifier(max_depth=1, random_state=853477355),
#  DecisionTreeClassifier(max_depth=1, random_state=1260522119),
#  DecisionTreeClassifier(max_depth=1, random_state=23717335),
#  DecisionTreeClassifier(max_depth=1, random_state=60472382),
#  DecisionTreeClassifier(max_depth=1, random_state=1354896522),
#  DecisionTreeClassifier(max_depth=1, random_state=854021618),
#  DecisionTreeClassifier(max_depth=1, random_state=888445520),
#  DecisionTreeClassifier(max_depth=1, random_state=907706759),
#  DecisionTreeClassifier(max_depth=1, random_state=983578274),
#  DecisionTreeClassifier(max_depth=1, random_state=1246294434),
#  DecisionTreeClassifier(max_depth=1, random_state=1165097248),
#  DecisionTreeClassifier(max_depth=1, random_state=455094650),
#  DecisionTreeClassifier(max_depth=1, random_state=318019332),
#  DecisionTreeClassifier(max_depth=1, random_state=1830948329),
#  DecisionTreeClassifier(max_depth=1, random_state=1539598566),
#  DecisionTreeClassifier(max_depth=1, random_state=648870905),
#  DecisionTreeClassifier(max_depth=1, random_state=497653800),
#  DecisionTreeClassifier(max_depth=1, random_state=1782238235),
#  DecisionTreeClassifier(max_depth=1, random_state=1559517318),
#  DecisionTreeClassifier(max_depth=1, random_state=1503404232),
#  DecisionTreeClassifier(max_depth=1, random_state=529561415),
#  DecisionTreeClassifier(max_depth=1, random_state=1930375947),
#  DecisionTreeClassifier(max_depth=1, random_state=1421196193),
#  DecisionTreeClassifier(max_depth=1, random_state=409783328),
#  DecisionTreeClassifier(max_depth=1, random_state=272981039),
#  DecisionTreeClassifier(max_depth=1, random_state=1592652278),
#  DecisionTreeClassifier(max_depth=1, random_state=1335658902),
#  DecisionTreeClassifier(max_depth=1, random_state=725167677),
#  DecisionTreeClassifier(max_depth=1, random_state=1396651735),
#  DecisionTreeClassifier(max_depth=1, random_state=712631076),
#  DecisionTreeClassifier(max_depth=1, random_state=986151010),
#  DecisionTreeClassifier(max_depth=1, random_state=392121003),
#  DecisionTreeClassifier(max_depth=1, random_state=590804839),
#  DecisionTreeClassifier(max_depth=1, random_state=1179921109),
#  DecisionTreeClassifier(max_depth=1, random_state=1663066074),
#  DecisionTreeClassifier(max_depth=1, random_state=263038498),
#  DecisionTreeClassifier(max_depth=1, random_state=2028147648),
#  DecisionTreeClassifier(max_depth=1, random_state=1644658402),
#  DecisionTreeClassifier(max_depth=1, random_state=513653348),
#  DecisionTreeClassifier(max_depth=1, random_state=2025988014),
#  DecisionTreeClassifier(max_depth=1, random_state=915879373),
#  DecisionTreeClassifier(max_depth=1, random_state=1498573442),
#  DecisionTreeClassifier(max_depth=1, random_state=1120063232),
#  DecisionTreeClassifier(max_depth=1, random_state=952321028),
#  DecisionTreeClassifier(max_depth=1, random_state=263183577),
#  DecisionTreeClassifier(max_depth=1, random_state=1013547510),
#  DecisionTreeClassifier(max_depth=1, random_state=1163795198),
#  DecisionTreeClassifier(max_depth=1, random_state=1099805069),
#  DecisionTreeClassifier(max_depth=1, random_state=2120835942),
#  DecisionTreeClassifier(max_depth=1, random_state=173660954),
#  DecisionTreeClassifier(max_depth=1, random_state=97636744),
#  DecisionTreeClassifier(max_depth=1, random_state=904790222),
#  DecisionTreeClassifier(max_depth=1, random_state=1836274702),
#  DecisionTreeClassifier(max_depth=1, random_state=476272473),
#  DecisionTreeClassifier(max_depth=1, random_state=109174313),
#  DecisionTreeClassifier(max_depth=1, random_state=1886935931),
#  DecisionTreeClassifier(max_depth=1, random_state=463390156),
#  DecisionTreeClassifier(max_depth=1, random_state=866377394)]

# %%
from sklearn import tree

for dt_tree in ada_clf.estimators_:
    # Plot all the decision trees
    fig = plt.figure(figsize=(3, 2))
    tree.plot_tree(dt_tree, filled=True, impurity=False)
    plt.show()
